# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import ast
sns.set()

# %%
data = pd.read_csv('das-data-sample-1.csv')

# %%
data.describe()
# Out:
#          type                                               item  \
# count    3627                                               3626
# unique      3                                               1560
# top     event  [{value=1, id=1852508, descr=, name=Chamados c...
# freq     1738                                                106
#
#                                                     host  \
# count                                               3627
# unique                                               186
# top     [{address=OTRS, name=OTRS, conn=172.16.255.202}]
# freq                                                 751
#
#                                                   trigger  \
# count                                                3626
# unique                                               1583
# top     [{severity=Information, descr=, nseverity=TRIG...
# freq                                                   56
#
# ...

# %%
data.head()
# Out:
#              type                                               item  \
# 0           event  [{value=88.34 MB, id=380343, descr=Available m...
# 1           event  [{value=960.17 Kbps, id=964714, descr=, name=T...
# 2           event  [{value=1, id=1852510, descr=, name=Chamados c...
# 3           event  [{value=1, id=1852522, descr=, name=Chamados c...
# 4  event_recovery  [{value=2019.03.30 14:51:15, id=873975, descr=...
#
#                                                 host  \
# 0  [{address=RDN-sle-vpn, name=RDN-sle-vpn, conn=...
# 1  [{address=router62, name=LBS-f62-router, conn=...
# 2   [{address=OTRS, name=OTRS, conn=172.16.255.202}]
# 3   [{address=OTRS, name=OTRS, conn=172.16.255.202}]
# 4  [{address=SV-CA-PPRD, name=SV-CA-PPRD, conn=10...
#
#                                              trigger  \
# 0  [{severity=Average, descr=, nseverity=3, hostg...
# 1  [{severity=High, descr=, nseverity=4, hostgrou...
# 2  [{severity=Information, descr=, nseverity=1, h...
# ...

# %%
a = data[['item']].iloc[0].values
