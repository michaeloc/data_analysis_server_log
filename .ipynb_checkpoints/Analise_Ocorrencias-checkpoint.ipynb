# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import ast
from tqdm import tqdm
sns.set()

from pyathena import connect

# %%
conn = connect(s3_staging_dir='s3://aws-athena-query-results-415718651610-us-east-1', region_name='us-east-1')
df = pd.read_sql("SELECT * FROM das.das_events limit 1", conn)

# %%
df.describe()
# Out:
#          type                        usc_das_id       e_id  \
# count       1                                 1          1
# unique      1                                 1          1
# top     event  yRkQEgqp9GWZz3B0LGdmwm75LbAnJ0OY  353836153
# freq        1                                 1          1
# first     NaN                               NaN        NaN
# last      NaN                               NaN        NaN
#
#                                                    e_name e_status e_severity  \
# count                                                   1        1          1
# unique                                                  1        1          1
# top     Zabbix agent on Jira App Producao is unreachab...  PROBLEM          3
# freq                                                    1        1          1
# first                                                 NaN      NaN        NaN
# last                                                  NaN      NaN        NaN
#
# ...

# %%
df.head()
# Out:
#     type                        usc_das_id       e_id  \
# 0  event  yRkQEgqp9GWZz3B0LGdmwm75LbAnJ0OY  353836153
#
#                                               e_name e_status e_severity  \
# 0  Zabbix agent on Jira App Producao is unreachab...  PROBLEM          3
#
#   e_tags              e_time     i_id i_value  \
# 0        2019-04-04 19:46:53  2254012  Up (1)
#
#                          ...                                  h_address  \
# 0                        ...                          Jira App Producao
#
#               h_name        h_conn    t_id t_severity t_descr t_nseverity  \
# 0  Jira App Producao  40.122.39.80  617993    Average                   3
#
#                                     t_hostgroup_name t_value  \
# 0  HG000000000038/SP/Matriz, HG000000000038/SP/Ma...       1
#
#                                               t_name
# 0  Zabbix agent on Jira App Producao is unreachab...
#
# [1 rows x 22 columns]

# %%
df.dropna(inplace=True)

# %%
table = pd.DataFrame(df)

# %%
table
# Out:
#     type                        usc_das_id       e_id  \
# 0  event  yRkQEgqp9GWZz3B0LGdmwm75LbAnJ0OY  353836153
#
#                                               e_name e_status e_severity  \
# 0  Zabbix agent on Jira App Producao is unreachab...  PROBLEM          3
#
#   e_tags              e_time     i_id i_value  \
# 0        2019-04-04 19:46:53  2254012  Up (1)
#
#                          ...                                  h_address  \
# 0                        ...                          Jira App Producao
#
#               h_name        h_conn    t_id t_severity t_descr t_nseverity  \
# 0  Jira App Producao  40.122.39.80  617993    Average                   3
#
#                                     t_hostgroup_name t_value  \
# 0  HG000000000038/SP/Matriz, HG000000000038/SP/Ma...       1
#
#                                               t_name
# 0  Zabbix agent on Jira App Producao is unreachab...
#
# [1 rows x 22 columns]

# %%
group = table.groupby('t_id')

# %%
group.all()
# Out:
#         type  usc_das_id  e_id  e_name  e_status  e_severity  e_tags  e_time  \
# t_id
# 617993  True        True  True    True      True        True   False    True
#
#         i_id  i_value   ...    i_name  h_address  h_name  h_conn  t_severity  \
# t_id                    ...
# 617993  True     True   ...      True       True    True    True        True
#
#         t_descr  t_nseverity  t_hostgroup_name  t_value  t_name
# t_id
# 617993    False         True              True     True    True
#
# [1 rows x 21 columns]

# %%
table[table['t_id']=='139076'].iloc[:,:15]

# %%
np.unique(table.i_id.values)

# %%
table[table['i_id']=='1070511'].iloc[:,:15]
